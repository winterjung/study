# %% [markdown]
# http://stackoverflow.com/questions/28867474/get-to-stream-tweets-from-users-a-user-is-following-using-tweepy
# https://dev.twitter.com/streaming/overview/connecting
# https://dev.twitter.com/streaming/reference/get/user
# https://dev.twitter.com/streaming/overview/request-parameters
# https://dev.twitter.com/streaming/userstreams

# %%
import tweepy
from tweepy.streaming import StreamListener

import sqlalchemy

# %%
C_KEY = "NEYWtiThh3aowDQnKpTxEZNy3"
C_SECRET = "4BOkLe2QVVUk4Vp5tJYVGW947BoRupLxEv9A0sQ8HMGSEBxs2A"
A_TOKEN = "850995925-BPaQZthVlpNuG5H5fjHyZnFDQEvs7vZD68CVkcFO"
A_SECRET = "zG1LJg79TXLBoBWmsvMczqslzA7FCs89HLNJWUG3F87Ik"

# %%
AUTH = tweepy.OAuthHandler(C_KEY, C_SECRET)
AUTH.set_access_token(A_TOKEN, A_SECRET)

API = tweepy.API(AUTH, wait_on_rate_limit=True,
                 wait_on_rate_limit_notify=True)

ME = API.me()
MY_NAME = '@' + (ME.screen_name).lower()

print(" * name: " + MY_NAME + " *")
# Out:
#  * name: @res_tin *

# %%
class Timeline(StreamListener):
    def on_status(self, status):
        print('>>> HELLO <<<')
        timelines = API.home_timeline()
        for timeline in timelines:
            print("=====timeline====")
            print(timeline.text)
        
        mentions = API.mentions_timeline(count=1)
        for mention in mentions:
            print("=====mentions====")
            print(mention.text)
        print(">>> BYE <<<")

# %%
listener = Timeline()
stream = tweepy.Stream(auth=AUTH, listener=listener)

# %%
stream.disconnect()

# %%
stream.filter(follow=["@res_tin"])

# %%
stream.userstream(_with='@res_tin', replies='all', stall_warnings=True)

# %%
stream.sitestream(follow=[AUTH.get_username()])

# %%
stream.userstream()

# %%
stream.userstream(_with='followings')
# Out:
# >>> HELLO <<<
# =====timeline====
# RT @CitrusTM: 님들아 아즈레아보다 편한 달새 쓰자 https://t.co/BNqQiIgGg4
# =====timeline====
# RT @if1live: AWS 의인화 : "인간이란 참 이상하다... 동접이 10명도 되지 않을텐데 로드밸런싱을 왜 밤새워 고민하는 것일까?" (...)
# =====timeline====
# RT @onmyruril: 때때로 직역체 문장은 묘하게 힙한 느낌이 들때가 있다..
# 힘세고 강한 부팅. 만일 내게 묻는다면 나는 게임. https://t.co/M6Elh4qoiO
# =====timeline====
# RT @aikozy: 깨알영어팁 숱을 치다라는 뜻의 영어표현은 trim입니다 trim 혹은 trimming해달라그러면 숱 많이 쳐줌
# =====timeline====
# RT @teoliphant: Looking forward to catching up with @GaelVaroquaux and others tonight and helping to jumpstart the @PyDataParis meetup #pyd…
# =====timeline====
# RT @hongyun_69: 우리동네ㅔㅋㅋㅋㅋㅇㅋㅇㅋㅋ저번에 카스테라 팔던집인데ㅔㅋㅋㅋ리뉴얼 중이라고 해서 응? 했더니ㅣㅋㅋㅇㅋㄱㅋㄱㅋㅇㅋㅇㅋㅇㅋㄱㅋㄱㅋㅋㅋㄱㅋㄱㅋㄱㅋㄱㅋㅋㅋㅋㅋ번창하세욬ㅋㅋㅋㅋ https://t.co/o7HaksEevr
# =====timeline====
# 목표는.. 공앱보단 쓸만하게 만들자?
# =====timeline====
# @_Maisie_CSE_ 집와서 한다며 ㅠㅠ 오늘은 못하는거야?
# =====timeline====
# RT @GongSa_04: https://t.co/DOYgGcXuIG
# 좋은 사이트 발견!
# 위에 상업적 이용을 하지 안할지 체크를 하고 검색하면
# 걸러서 뽑아줌! 사진 찾다가 알게됐다 😇
# 이미지,노래,동영상 찾아주니까 좋은것같아요! https://t.c…
# =====timeline====
# 불가사의는 총 몇 개? https://t.co/LrQpdAQOGD
# =====timeline====
# @res_tin 내일 제대로 해보겟어
# =====timeline====
# 으 탐라읽을 힘 없어..
# =====timeline====
# @_Maisie_CSE_ 앗 그래? 난 왜 되는거지...
# =====timeline====
# 인스타그램이 업데이트 되더니 flickr에 같이 포스팅 하는 기능이 없어졌어 ㅠ 이럴수가
# IFTTT 를 연결해야 하나 ㅠ
# =====timeline====
# @res_tin 했는데 안되서,,,,
# =====timeline====
# RT @inventeam: 갓갓으로 불리는 게임, &lt;#위쳐&gt;의 소설 속 이야기가 드라마로 제작됩니다! '마르코폴로'로 '#왕좌의게임'급 스케일을 보여준 넷플릭스라 그런지 믿음이 가네요ㅎ https://t.co/VWRMWmttqn https://t.c…
# =====timeline====
# iovisor / bcc: BCC - Tools for BPF-based Linux IO analysis, networking, monitoring, and more ★2878 https://t.co/RKfugM6bKJ #C++
# =====timeline====
# Just posted a photo @ 이태리부대찌개 https://t.co/Ch1hsAq5RO
# =====timeline====
# @_Maisie_CSE_ 디디맨 stream.userstream(_with='followings') 하면 된다 ~_~ 이제 천국가자
# =====timeline====
# RT @mamgon: あのシーンで事故る山田エルフ先生 https://t.co/ONk74lmoo9
# =====mentions====
# @res_tin 내일 제대로 해보겟어
# >>> BYE <<<
# >>> HELLO <<<
# =====timeline====
# &lt;del&gt;Arcane&lt;/del&gt; AVR dev board, AVR Butterfly. https://t.co/IGvGjBtYhp
# =====timeline====
# RT @CitrusTM: 님들아 아즈레아보다 편한 달새 쓰자 https://t.co/BNqQiIgGg4
# =====timeline====
# RT @if1live: AWS 의인화 : "인간이란 참 이상하다... 동접이 10명도 되지 않을텐데 로드밸런싱을 왜 밤새워 고민하는 것일까?" (...)
# =====timeline====
# RT @onmyruril: 때때로 직역체 문장은 묘하게 힙한 느낌이 들때가 있다..
# 힘세고 강한 부팅. 만일 내게 묻는다면 나는 게임. https://t.co/M6Elh4qoiO
# =====timeline====
# RT @aikozy: 깨알영어팁 숱을 치다라는 뜻의 영어표현은 trim입니다 trim 혹은 trimming해달라그러면 숱 많이 쳐줌
# =====timeline====
# RT @teoliphant: Looking forward to catching up with @GaelVaroquaux and others tonight and helping to jumpstart the @PyDataParis meetup #pyd…
# =====timeline====
# RT @hongyun_69: 우리동네ㅔㅋㅋㅋㅋㅇㅋㅇㅋㅋ저번에 카스테라 팔던집인데ㅔㅋㅋㅋ리뉴얼 중이라고 해서 응? 했더니ㅣㅋㅋㅇㅋㄱㅋㄱㅋㅇㅋㅇㅋㅇㅋㄱㅋㄱㅋㅋㅋㄱㅋㄱㅋㄱㅋㄱㅋㅋㅋㅋㅋ번창하세욬ㅋㅋㅋㅋ https://t.co/o7HaksEevr
# =====timeline====
# 목표는.. 공앱보단 쓸만하게 만들자?
# =====timeline====
# @_Maisie_CSE_ 집와서 한다며 ㅠㅠ 오늘은 못하는거야?
# =====timeline====
# RT @GongSa_04: https://t.co/DOYgGcXuIG
# 좋은 사이트 발견!
# 위에 상업적 이용을 하지 안할지 체크를 하고 검색하면
# 걸러서 뽑아줌! 사진 찾다가 알게됐다 😇
# 이미지,노래,동영상 찾아주니까 좋은것같아요! https://t.c…
# =====timeline====
# 불가사의는 총 몇 개? https://t.co/LrQpdAQOGD
# =====timeline====
# @res_tin 내일 제대로 해보겟어
# =====timeline====
# 으 탐라읽을 힘 없어..
# =====timeline====
# @_Maisie_CSE_ 앗 그래? 난 왜 되는거지...
# =====timeline====
# 인스타그램이 업데이트 되더니 flickr에 같이 포스팅 하는 기능이 없어졌어 ㅠ 이럴수가
# IFTTT 를 연결해야 하나 ㅠ
# =====timeline====
# @res_tin 했는데 안되서,,,,
# =====timeline====
# RT @inventeam: 갓갓으로 불리는 게임, &lt;#위쳐&gt;의 소설 속 이야기가 드라마로 제작됩니다! '마르코폴로'로 '#왕좌의게임'급 스케일을 보여준 넷플릭스라 그런지 믿음이 가네요ㅎ https://t.co/VWRMWmttqn https://t.c…
# =====timeline====
# iovisor / bcc: BCC - Tools for BPF-based Linux IO analysis, networking, monitoring, and more ★2878 https://t.co/RKfugM6bKJ #C++
# =====timeline====
# Just posted a photo @ 이태리부대찌개 https://t.co/Ch1hsAq5RO
# =====timeline====
# @_Maisie_CSE_ 디디맨 stream.userstream(_with='followings') 하면 된다 ~_~ 이제 천국가자
# =====mentions====
# @res_tin 내일 제대로 해보겟어
# >>> BYE <<<
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-28810297100b> in <module>()
# ----> 1 stream.userstream(_with='followings')
#
# c:\python35\lib\site-packages\tweepy\streaming.py in userstream(self, stall_warnings, _with, replies, track, locations, async, encoding)
#     392             self.session.params['track'] = u','.join(track).encode(encoding)
#     393
# --> 394         self._start(async)
#     395
#     396     def firehose(self, count=None, async=False):
#
# c:\python35\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# c:\python35\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# c:\python35\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# c:\python35\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# c:\python35\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     378             else:
#     379                 cache_content = False
# --> 380                 data = self._fp.read(amt)
#     381                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     382                     # Close the connection when no data is returned
#
# c:\python35\lib\http\client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# c:\python35\lib\http\client.py in readinto(self, b)
#     476
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#     480         if self.length is not None:
#
# c:\python35\lib\http\client.py in _readinto_chunked(self, b)
#     571         try:
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#     575                     return total_bytes
#
# c:\python35\lib\http\client.py in _get_chunk_left(self)
#     539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
# --> 541                 chunk_left = self._read_next_chunk_size()
#     542             except ValueError:
#     543                 raise IncompleteRead(b'')
#
# c:\python35\lib\http\client.py in _read_next_chunk_size(self)
#     499     def _read_next_chunk_size(self):
#     500         # Read the next chunk size from the file
# --> 501         line = self.fp.readline(_MAXLINE + 1)
#     502         if len(line) > _MAXLINE:
#     503             raise LineTooLong("chunk size")
#
# c:\python35\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# c:\python35\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\python35\lib\ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\python35\lib\ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
